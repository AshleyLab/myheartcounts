# %%
rm(list=ls())
library(ggplot2)

# %%
hk_data=read.table("../../../data/tables/cardiovascular-HealthKitDataCollector-v1.tsv",header=TRUE,sep='\t')

# %%
head(hk_data)
# Out:
#   ROW_ID ROW_VERSION recordId                             appVersion phoneInfo
# 1 0      0           f7e3d221-5109-4b38-9873-02976b7787b2 NA         NA
# 2 1      0           17c81804-281d-4ecc-86b0-b81a844482a7 NA         NA
# 3 2      0           b5a0e535-dfa8-4fdc-84d0-6b87306b32b7 NA         NA
# 4 3      0           924542d0-1985-4a1f-be23-c0c39e35ea26 NA         NA
# 5 4      0           e8048285-b94d-4ca8-bbfa-b9a7c4b08ae4 NA         NA
# 6 5      0           4e941131-a099-4496-812e-19aed80fda6b NA         NA
#   uploadDate healthCode                           externalId dataGroups
# 1 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
# 2 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
# 3 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
# 4 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
# 5 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
# 6 2015-04-14 a63a89b7-952a-417b-a3f0-98b89756bf51 NA         NA
#   createdOn           createdOnTimeZone userSharingScope validationErrors
# 1 2015-04-14 00:22:49 NA                NA               NA
# 2 2015-04-13 23:47:30 NA                NA               NA
# 3 2015-04-14 00:22:49 NA                NA               NA
# 4 2015-04-13 23:47:30 NA                NA               NA
# 5 2015-04-13 23:47:30 NA                NA               NA
# 6 2015-04-14 00:22:49 NA                NA               NA
#   substudyMemberships dayInStudy data.csv rawData
# 1 NA                  NA         3065654  NA
# 2 NA                  NA         3066523  NA
# 3 NA                  NA         3066746  NA
# 4 NA                  NA         3066829  NA
# 5 NA                  NA         3066966  NA
# 6 NA                  NA         3067081  NA

# %%
hk_data$uploadDate=as.Date(hk_data$uploadDate)

# %%
min(hk_data$uploadDate)
# Out:
# [1] "2015-04-14"

# %%
max(hk_data$uploadDate)
# Out:
# [1] "2020-04-04"

# %%
library(repr)
options(repr.plot.width=10, repr.plot.height=4)
ggplot(data=hk_data,
      aes(x=hk_data$uploadDate))+
geom_histogram(bins=100)+
xlab("uploadDate")+
ylab("HealthKitDataCollector")+
theme_bw(20)+
ggtitle(paste(min(hk_data$uploadDate),'-',max(hk_data$uploadDate)))
# Out:
# Warning message:
# “Use of `hk_data$uploadDate` is discouraged. Use `uploadDate` instead.”
# plot without title

# %%
hk_data$createdOn=as.Date(hk_data$createdOn)

# %%
ggplot(data=hk_data,
      aes(x=createdOn,
         y=uploadDate))+
geom_point(alpha=0.01)+
xlab("createdOn")+
ylab("uploadDate")
# Out:
# plot without title
